# %% [markdown]
# # LLM Prompt Engineering Evaluation Report

# %% [markdown]
# ## 1. Introduction
# This report analyzes the performance of 6 prompting techniques across Summarization, Code Generation, and Reasoning tasks.

# %% [markdown]
# ## 2. Methodology
# Techniques tested:
# - Zero-shot
# - Few-shot
# - Chain-of-Thought
# - Role-based
# - Tree-of-Thought
# - Structured Output

# %% [markdown]
# ## 3. Results Overview
# Below are visualizations summarizing our empirical findings based on multiple independent runs.

# %%
import pandas as pd
df = pd.read_csv('../results/statistics.csv')
print(df.groupby(['Task', 'Technique'])['Mean'].mean().unstack())

# %% [markdown]
# ## Visualizations
# ### ROUGE-L Average Score per Technique

# %% [markdown]
# <img src="../charts/rouge_bar.png" width="600" />

# %% [markdown]
# ### Consistency (Boxplot)

# %% [markdown]
# <img src="../charts/variance_boxplot.png" width="600" />

# %% [markdown]
# ### Best Techniques Matrix (Heatmap)

# %% [markdown]
# <img src="../charts/heatmap.png" width="600" />

# %% [markdown]
# ### Stability Across Runs (Lineplot)

# %% [markdown]
# <img src="../charts/stability_lineplot.png" width="600" />

# %% [markdown]
# ## 4. Conclusions
# The empirical data strongly highlights the consistency of prompt patterns compared across tasks.
